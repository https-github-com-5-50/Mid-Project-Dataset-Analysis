# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
import koreanize_matplotlib
# %config InlineBackend.figure_format = 'retina'

# %%
from glob import glob

file_name = glob("data/서울*.csv")[3]
file_name
# Out:
# 'data\\서울시_우리마을가게_상권분석서비스(신_상권_점포)_2021년.csv'

# %%
df1 = pd.read_csv(file_name, encoding="cp949")
df1.head(10)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100008
# 2     2021         1        A       골목상권  2110001  이북5도청사  CS100009
# 3     2021         1        A       골목상권  2110001  이북5도청사  CS100010
# 4     2021         1        A       골목상권  2110001  이북5도청사  CS200001
# 5     2021         1        A       골목상권  2110001  이북5도청사  CS200008
# 6     2021         1        A       골목상권  2110001  이북5도청사  CS200016
# 7     2021         1        A       골목상권  2110001  이북5도청사  CS200017
# 8     2021         1        A       골목상권  2110001  이북5도청사  CS200028
# 9     2021         1        A       골목상권  2110001  이북5도청사  CS200033
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0       한식음식점    10          11     0        0     0        0           1
# ...

# %%
df1.shape
# Out:
# (299164, 15)

# %%
df1.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100008
# 2     2021         1        A       골목상권  2110001  이북5도청사  CS100009
# 3     2021         1        A       골목상권  2110001  이북5도청사  CS100010
# 4     2021         1        A       골목상권  2110001  이북5도청사  CS200001
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0       한식음식점    10          11     0        0     0        0           1
# 1       분식전문점     3           3     0        0     0        0           0
# 2     호프-간이주점     1           2     0        0     0        0           1
# 3       커피-음료     2           2     0        0     0        0           0
# 4      일반교습학원     3           3     0        0     0        0           0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299164 entries, 0 to 299163
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   기준_년_코드      299164 non-null  int64
#  1   기준_분기_코드     299164 non-null  int64
#  2   상권_구분_코드     299164 non-null  object
#  3   상권_구분_코드_명   299164 non-null  object
#  4   상권_코드        299164 non-null  int64
#  5   상권_코드_명      299164 non-null  object
#  6   서비스_업종_코드    299164 non-null  object
#  7   서비스_업종_코드_명  299164 non-null  object
#  8   점포_수         299164 non-null  int64
#  9   유사_업종_점포_수   299164 non-null  int64
#  10  개업_율         299164 non-null  int64
#  11  개업_점포_수      299164 non-null  int64
#  12  폐업_률         299164 non-null  int64
#  13  폐업_점포_수      299164 non-null  int64
#  14  프랜차이즈_점포_수   299164 non-null  int64
# dtypes: int64(10), object(5)
# memory usage: 34.2+ MB

# %%
df1.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 상권_구분_코드       0
# 상권_구분_코드_명     0
# 상권_코드          0
# 상권_코드_명        0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 유사_업종_점포_수     0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')

# %%
df1.columns.str.strip()
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수',
#        '폐업_률', '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')

# %%
df1["상권_코드_명"].value_counts().index
# Out:
# Index(['강남역', '신논현역', '역삼역', '명동 남대문 북창동 다동 무교동 관광특구', '교대역(법원.검찰청)',
#        '종로·청계 관광특구', '총신대입구역(이수, 총신대)', '연남동(홍대)', '교대입구교차로', '뱅뱅사거리',
#        ...
#        '양남시장', '청계5가쇼핑센터(청계5가지하쇼핑센터)', '에리어식스(벨포스트)', '동서시장', '수유북부골목시장',
#        '박미시장(기능상실)', '동문시장', '푸른터시장(기능상실)', '번동시장', '영등포시장지하도상점가'],
#       dtype='object', length=1665)

# %%
df1["서비스_업종_코드_명"].value_counts().index
# Out:
# Index(['한식음식점', '슈퍼마켓', '일반의류', '미용실', '커피-음료', '부동산중개업', '분식전문점', '반찬가게',
#        '편의점', '화장품', '전자상거래업', '호프-간이주점', '인테리어', '의약품', '치킨전문점', '세탁소',
#        '일반교습학원', '제과점', '피부관리실', '육류판매', '중식음식점', '컴퓨터및주변장치판매', '예술학원',
#        '패스트푸드점', '스포츠 강습', '철물점', '일식음식점', '화초', '양식음식점', '문구', '노래방', '일반의원',
#        '자동차수리', '핸드폰', '청과상', '외국어학원', '사진관', '치과의원', '당구장', '조명용품', '운동/경기용품',
#        '가전제품', '한의원', '섬유제품', '서적', '가전제품수리', '가구', '애완동물', '시계및귀금속', '안경',
#        '신발', '기타오락장', '미곡판매', '네일숍', '의료기기', '자동차부품', '여행사', '수산물판매', '여관',
#        'PC방', '가방', '건축물청소', '스포츠클럽', '세무사사무소', '독서실', '예술품', '자동차미용', '유아의류',
#        '주류도매', '미용재료', '골프연습장', '완구', '모터사이클수리', '동물병원', '복권방', '재생용품 판매점',
#        '주유소', '통신기기수리', '법무사사무소', '고시원', '악기', '기타법무서비스', '회계사사무소', '비디오/서적임대',
#        '모터사이클및부품', '가정용품임대', '자전거 및 기타운송장비', '변호사사무소', '통번역서비스', '녹음실', '한복점',
#        '게스트하우스', 'DVD방', '의류임대', '컴퓨터학원', '변리사사무소', '중고차판매', '전자게임장', '볼링장',
#        '중고가구'],
#       dtype='object')

# %%
df1 = df1.drop_duplicates()

# %% [markdown]
# ## 별도로 추출한 상권코드 결합하기

# %%
df2 = pd.read_csv("data/행정동_시군구연결_중복제거.csv",encoding="cp949").drop_duplicates()
df2
# Out:
#       기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0       202112        A       골목상권  2110753   시흥동 은행나무사거리  191934  438813
# 1       202112        A       골목상권  2110427    노원 을지대학교병원  206265  459431
# 2       202112        A       골목상권  2110755      동일여자고등학교  192300  439070
# 3       202112        A       골목상권  2110739    시흥3동 우편취급국  191289  438014
# 4       202112        A       골목상권  2111017      송파나루역 3번  210222  445516
# ...        ...      ...        ...      ...           ...     ...     ...
# 1666    202112        U       관광특구  1001493  동대문패션타운 관광특구  200974  451975
# 1667    202112        U       관광특구  1001494    종로?청계 관광특구  199768  452273
# 1668    202112        U       관광특구  1001495       잠실 관광특구  210191  446339
# 1669    202112        U       관광특구  1001496   강남 마이스 관광특구  205310  445727
# 1670    202112        U       관광특구  1001491      이태원 관광특구  199503  448326
#
#       시군구_코드    행정동_코드     행정동코드         행정동명 시군구명
# ...

# %%
df2.shape
# Out:
# (1671, 12)

# %%
df2 = df2[["상권_코드", "시군구명", "행정동명"]]
df2
# Out:
#         상권_코드 시군구명         행정동명
# 0     2110753  금천구         시흥5동
# 1     2110427  노원구         하계1동
# 2     2110755  금천구         시흥2동
# 3     2110739  금천구         시흥3동
# 4     2111017  송파구         방이2동
# ...       ...  ...          ...
# 1666  1001493   중구          광희동
# 1667  1001494  종로구  종로1.2.3.4가동
# 1668  1001495  송파구          오륜동
# 1669  1001496  강남구         삼성1동
# 1670  1001491  용산구        이태원1동
#
# [1671 rows x 3 columns]

# %%
df = df1.merge(df2, on="상권_코드", how="left")
df.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100008
# 2     2021         1        A       골목상권  2110001  이북5도청사  CS100009
# 3     2021         1        A       골목상권  2110001  이북5도청사  CS100010
# 4     2021         1        A       골목상권  2110001  이북5도청사  CS200001
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# 0       한식음식점    10          11     0        0     0        0           1
# 1       분식전문점     3           3     0        0     0        0           0
# 2     호프-간이주점     1           2     0        0     0        0           1
# 3       커피-음료     2           2     0        0     0        0           0
# 4      일반교습학원     3           3     0        0     0        0           0
#
#   시군구명 행정동명
# 0  종로구  평창동
# 1  종로구  평창동
# 2  종로구  평창동
# 3  종로구  평창동
# 4  종로구  평창동

# %%
df.isnull().sum()
# Out:
# 기준_년_코드        0
# 기준_분기_코드       0
# 상권_구분_코드       0
# 상권_구분_코드_명     0
# 상권_코드          0
# 상권_코드_명        0
# 서비스_업종_코드      0
# 서비스_업종_코드_명    0
# 점포_수           0
# 유사_업종_점포_수     0
# 개업_율           0
# 개업_점포_수        0
# 폐업_률           0
# 폐업_점포_수        0
# 프랜차이즈_점포_수     0
# 시군구명           0
# 행정동명           0
# dtype: int64

# %%
df.shape
# Out:
# (299164, 17)

# %% [markdown]
# ## 필요한 컬럼만 추출하기

# %%
df = df[["상권_코드", "시군구명", "행정동명","서비스_업종_코드_명"]]
df
# Out:
#           상권_코드 시군구명  행정동명 서비스_업종_코드_명
# 0       2110001  종로구   평창동       한식음식점
# 1       2110001  종로구   평창동       분식전문점
# 2       2110001  종로구   평창동     호프-간이주점
# 3       2110001  종로구   평창동       커피-음료
# 4       2110001  종로구   평창동      일반교습학원
# ...         ...  ...   ...         ...
# 299159  1001496  강남구  삼성1동        조명용품
# 299160  1001496  강남구  삼성1동       자동차부품
# 299161  1001496  강남구  삼성1동         예술품
# 299162  1001496  강남구  삼성1동         주유소
# 299163  1001496  강남구  삼성1동      전자상거래업
#
# [299164 rows x 4 columns]

# %%
df.head(10)
# Out:
#      상권_코드 시군구명 행정동명 서비스_업종_코드_명
# 0  2110001  종로구  평창동       한식음식점
# 1  2110001  종로구  평창동       분식전문점
# 2  2110001  종로구  평창동     호프-간이주점
# 3  2110001  종로구  평창동       커피-음료
# 4  2110001  종로구  평창동      일반교습학원
# 5  2110001  종로구  평창동         한의원
# 6  2110001  종로구  평창동         당구장
# 7  2110001  종로구  평창동       골프연습장
# 8  2110001  종로구  평창동         미용실
# 9  2110001  종로구  평창동      부동산중개업

# %%
df.sample(10)
# Out:
#           상권_코드  시군구명   행정동명 서비스_업종_코드_명
# 164584  2110371   강북구    송천동         핸드폰
# 145680  2130230   구로구   가리봉동         네일숍
# 95207   2110493  서대문구  북가좌1동         당구장
# 111761  2110881   관악구    대학동        가전제품
# 173063  2110568   마포구    서강동       한식음식점
# 101335  2110639   강서구   방화1동         화장품
# 138877  2130035    중구   을지로동          가방
# 6752    2110171   광진구   중곡4동        육류판매
# 244757  2110490   은평구    녹번동       건축물청소
# 164920  2110378   강북구    송중동        육류판매

# %%
df.describe()
# Out:
#               상권_코드
# count  2.991640e+05
# mean   2.108136e+06
# std    9.193178e+04
# min    1.001491e+06
# 25%    2.110441e+06
# 50%    2.110877e+06
# 75%    2.120146e+06
# max    2.130326e+06

# %%
df["서비스_업종_코드_명"]
# Out:
# 0           한식음식점
# 1           분식전문점
# 2         호프-간이주점
# 3           커피-음료
# 4          일반교습학원
#            ...
# 299159       조명용품
# 299160      자동차부품
# 299161        예술품
# 299162        주유소
# 299163     전자상거래업
# Name: 서비스_업종_코드_명, Length: 299164, dtype: object

# %% [markdown]
# ## 중복 제거하기

# %%
df= df.drop_duplicates(['행정동명', '서비스_업종_코드_명'])
df
# Out:
#           상권_코드 시군구명     행정동명 서비스_업종_코드_명
# 0       2110001  종로구      평창동       한식음식점
# 1       2110001  종로구      평창동       분식전문점
# 2       2110001  종로구      평창동     호프-간이주점
# 3       2110001  종로구      평창동       커피-음료
# 4       2110001  종로구      평창동      일반교습학원
# ...         ...  ...      ...         ...
# 287089  2120241  송파구     거여2동       기타오락장
# 289374  2130064  성동구  금호2.3가동      가전제품수리
# 297336  2130295  관악구      인헌동     기타법무서비스
# 297356  2130295  관악구      인헌동        주류도매
# 298389  2130320  강동구     암사1동        미용재료
#
# [29512 rows x 4 columns]

# %%
df["서비스_업종_코드_명"].describe(include = "O")
# Out:
# count     29512
# unique      100
# top       한식음식점
# freq        400
# Name: 서비스_업종_코드_명, dtype: object

# %%
# 중복 제거 확인
df.groupby("행정동명")["서비스_업종_코드_명"].describe()
# Out:
#      count unique    top freq
# 행정동명
# 가락1동    36     36  한식음식점    1
# 가락2동    77     77  한식음식점    1
# 가락본동    94     94  한식음식점    1
# 가리봉동    78     78  한식음식점    1
# 가산동     94     94  한식음식점    1
# ...    ...    ...    ...  ...
# 효창동     64     64  한식음식점    1
# 후암동     75     75  한식음식점    1
# 휘경1동    74     74  한식음식점    1
# 휘경2동    55     55  한식음식점    1
# 흑석동     66     66  한식음식점    1
#
# [401 rows x 4 columns]

# %%
# df.to_csv("서비스_업종_코드_명_중복제거.csv", index=False)

# %%
# df = pd.read_csv("서비스_업종_코드_명_중복제거.csv")
df_1 = df.sort_values(by=["시군구명"])
df_1
# Out:
#          상권_코드 시군구명    행정동명 서비스_업종_코드_명
# 39693  2110957  강남구    논현2동       일식음식점
# 58779  2120190  강남구    압구정동         여행사
# 58780  2120190  강남구    압구정동    비디오/서적임대
# 58782  2120190  강남구    압구정동      가정용품임대
# 58783  2120190  강남구    압구정동        슈퍼마켓
# ...        ...  ...     ...         ...
# 10482  2110259  중랑구  면목3.8동          여관
# 10483  2110259  중랑구  면목3.8동         노래방
# 10484  2110259  중랑구  면목3.8동        DVD방
# 10477  2110259  중랑구  면목3.8동         네일숍
# 66664  2130113  중랑구    신내2동      패스트푸드점
#
# [29512 rows x 4 columns]

# %%
# 깃헙에 업로드한 업종 개수 자료
df_1.to_csv("업종명.csv", index=False)

# %%
df_count = df_1.groupby("행정동명")["서비스_업종_코드_명"].value_counts()
df_count.sample(30)
# Out:
# 행정동명    서비스_업종_코드_명
# 망원2동    세무사사무소         1
# 송파1동    반찬가게           1
# 정릉3동    화초             1
# 번1동     조명용품           1
# 평창동     주류도매           1
# 사당3동    노래방            1
# 청림동     스포츠 강습         1
# 양평2동    법무사사무소         1
# 삼선동     모터사이클및부품       1
# 시흥1동    가전제품수리         1
# 방화2동    모터사이클및부품       1
# 대조동     육류판매           1
# 오륜동     스포츠 강습         1
# 신월6동    커피-음료          1
# 수유2동    분식전문점          1
# 염리동     예술학원           1
# 후암동     인테리어           1
# 대림1동    스포츠클럽          1
# 난곡동     건축물청소          1
# 홍은2동    서적             1
# 대흥동     전자상거래업         1
# 이촌1동    일반의류           1
# 마천2동    패스트푸드점         1
# 구로4동    인테리어           1
# 전농2동    제과점            1
# 신월4동    수산물판매          1
# 면목3.8동  주유소            1
# 안암동     가구             1
# 반포4동    통신기기수리         1
# 신사2동    PC방            1
# Name: 서비스_업종_코드_명, dtype: int64

# %%
df_group = df_1.groupby(["시군구명", "행정동명"])
df_group2 = df_group[["서비스_업종_코드_명"]].count()

# %%
df_group2
# Out:
#            서비스_업종_코드_명
# 시군구명 행정동명
# 강남구  개포1동            7
#      개포2동           73
#      개포4동           77
#      논현1동           98
#      논현2동           98
# ...                ...
# 중랑구  상봉2동           95
#      신내1동           77
#      신내2동           48
#      중화1동           71
#      중화2동           81
#
# [402 rows x 1 columns]

# %%
df_group2 = df_group2.reset_index()

# %%
df_group2
# Out:
#     시군구명  행정동명  서비스_업종_코드_명
# 0    강남구  개포1동            7
# 1    강남구  개포2동           73
# 2    강남구  개포4동           77
# 3    강남구  논현1동           98
# 4    강남구  논현2동           98
# ..   ...   ...          ...
# 397  중랑구  상봉2동           95
# 398  중랑구  신내1동           77
# 399  중랑구  신내2동           48
# 400  중랑구  중화1동           71
# 401  중랑구  중화2동           81
#
# [402 rows x 3 columns]

# %%
# 시군구별 업종 개수 그래프를 위한 데이터
df_drop = df_1.drop_duplicates(['시군구명','서비스_업종_코드_명'])
df_drop
# Out:
#          상권_코드 시군구명  행정동명 서비스_업종_코드_명
# 39693  2110957  강남구  논현2동       일식음식점
# 58779  2120190  강남구  압구정동         여행사
# 58780  2120190  강남구  압구정동    비디오/서적임대
# 58782  2120190  강남구  압구정동      가정용품임대
# 58783  2120190  강남구  압구정동        슈퍼마켓
# ...        ...  ...   ...         ...
# 50221  2120069  중랑구  상봉2동       중고차판매
# 50188  2120069  중랑구  상봉2동        의류임대
# 50184  2120069  중랑구  상봉2동        DVD방
# 50180  2120069  중랑구  상봉2동      게스트하우스
# 50160  2120069  중랑구  상봉2동      변리사사무소
#
# [2479 rows x 4 columns]

# %%
# 매출과 비교하기 위한 자료
# df.to_csv("동별업종개수.csv", index=False)

# %%
# pd.read_csv("동별업종개수.csv", encoding="utf-8")

# %%
# 시군구별 업종 개수
px.histogram(df_drop, x="시군구명", y="서비스_업종_코드_명", histfunc="count")
# Out:
# <div>                            <div id="8795ce2e-711e-4fb2-988d-b0466c229583" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8795ce2e-711e-4fb2-988d-b0466c229583")) {                    Plotly.newPlot(                        "8795ce2e-711e-4fb2-988d-b0466c229583",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"count","hovertemplate":"\uc2dc\uad70\uad6c\uba85=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\uac15\ub0a8\uad6c","\ua
# ...

# %%
df_drop.groupby("시군구명")["행정동명"].count().plot(kind="bar",figsize=(10,5), rot=70)
# Out:
# <AxesSubplot:xlabel='시군구명'>

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df_drop, x="시군구명",
              order = df_drop["시군구명"].value_counts().index)
plt.title("시군구별 업종 개수", fontsize=15)
# Out:
# Text(0.5, 1.0, '시군구별 업종 개수')

# %% [markdown]
# ## 매출 데이터와 업종 데이터 상관계수 구하기

# %%
df_매출 = pd.read_csv('data/서울시_우리마을가게_상권분석서비스(신_상권_추정매출)_2021년.csv', encoding="cp949")
df_매출.head(2)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100008
#
#   서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 0       한식음식점  626851391      25502  ...              157     15667      7253
# 1       분식전문점  122957138      12039  ...                0      6679      4293
#
#    연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# 0           108          1098          2013          4344          7792
# 1            52           926          1222          2698          3404
#
#    연령대_60_이상_매출_건수  점포수
# 0             7568   28
# 1             2670    9
#
# [2 rows x 80 columns]

# %%
df_매출_columns = df_매출.columns
drop_columns = [col for col in df_1_columns if "비율" in col]

# %%
df_매출 = df_매출.drop(columns=drop_columns, axis=1)

# %%
df_매출.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_금액',
#        '주말_매출_금액', '월요일_매출_금액', '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액',
#        '금요일_매출_금액', '토요일_매출_금액', '일요일_매출_금액', '시간대_00~06_매출_금액',
#        '시간대_06~11_매출_금액', '시간대_11~14_매출_금액', '시간대_14~17_매출_금액',
#        '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액',
#        '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액',
#        '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수', '주말_매출_건수', '월요일_매출_건수',
#        '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수', '금요일_매출_건수', '토요일_매출_건수',
#        '일요일_매출_건수', '시간대_건수~06_매출_건수', '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수',
#        '시간대_건수~17_매출_건수', '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수',
#        '여성_매출_건수', '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수',
#        '연령대_40_매출_건수', '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수'],
#       dtype='object')

# %%
df_매출 = df_매출.drop(columns=["주중_매출_금액","주말_매출_금액",'주중_매출_건수',
       '주말_매출_건수'],axis=1)

# %%
region = pd.read_csv('data/상권코드.csv', encoding="utf-8")

# %%
region = region.drop_duplicates()

# %%
region.head(2)
# Out:
#     기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0     202112        A       골목상권  2110753  시흥동 은행나무사거리  191934  438813
# 34    202112        A       골목상권  2110427   노원 을지대학교병원  206265  459431
#
#     시군구_코드    행정동_코드     행정동코드  행정동명 시군구명
# 0    11545  11545710  11545710  시흥5동  금천구
# 34   11350  11350611  11350611  하계1동  노원구

# %%
df_2 = region[["상권_코드","행정동_코드","행정동명","시군구명"]]

# %%
df_price = df_매출.merge(df_2, on="상권_코드", how="left")

# %%
df_price = df_price.drop_duplicates()
df_price [df_price["행정동명"]=="개포1동"]
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드    상권_코드_명 서비스_업종_코드  \
# 18114     2021         1        A       골목상권  2110993  개포지하차도 북측  CS200028
# 53550     2021         2        A       골목상권  2110993  개포지하차도 북측  CS200028
# 88857     2021         3        A       골목상권  2110993  개포지하차도 북측  CS200028
#
#       서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  연령대_10_매출_건수  연령대_20_매출_건수  \
# 18114         미용실    2274308         89  ...             0             0
# 53550         미용실    2174704         88  ...             0             0
# 88857         미용실    2943873        133  ...             0             0
#
#        연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수  점포수  \
# 18114            16            17            18               38    3
# 53550            32             0            17               39    3
# 88857            40             6            38               49    3
#
#          행정동_코드  행정동명  시군구명
# 18114  11680660  개포1동   강남구
# ...

# %%
df_p = df_price[["시군구명","행정동명","분기당_매출_금액","점포수"]]
df_p = df_p.groupby(["시군구명","행정동명"]).sum()
df_p = df_p.reset_index()
df_p
# Out:
#     시군구명  행정동명      분기당_매출_금액    점포수
# 0    강남구  개포1동        7392885      9
# 1    강남구  개포2동   101172867848   3526
# 2    강남구  개포4동   122071403738   2019
# 3    강남구  논현1동  1435833997837  22093
# 4    강남구  논현2동   518011005206  11567
# ..   ...   ...            ...    ...
# 396  중랑구  상봉2동   280294948942   6611
# 397  중랑구  신내1동    94679741672   3762
# 398  중랑구  신내2동    31058091900    969
# 399  중랑구  중화1동    44189026709   1861
# 400  중랑구  중화2동   124583027209   4189
#
# [401 rows x 4 columns]

# %%
df_매출
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2021         1        A       골목상권  2110001       이북5도청사  CS100001
# 1          2021         1        A       골목상권  2110001       이북5도청사  CS100008
# 2          2021         1        A       골목상권  2110001       이북5도청사  CS100009
# 3          2021         1        A       골목상권  2110001       이북5도청사  CS100010
# 4          2021         1        A       골목상권  2110001       이북5도청사  CS200001
# ...         ...       ...      ...        ...      ...          ...       ...
# 140825     2021         4        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# 140826     2021         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 140827     2021         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 140828     2021         4        U       관광특구  1001496  강남 마이스 관광특구  CS300035
# 140829     2021         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
#
# ...

# %%
df_2
# Out:
#           상권_코드    행정동_코드         행정동명 시군구명
# 0       2110753  11545710         시흥5동  금천구
# 34      2110427  11350611         하계1동  노원구
# 68      2110755  11545680         시흥2동  금천구
# 102     2110739  11545690         시흥3동  금천구
# 136     2111017  11710562         방이2동  송파구
# ...         ...       ...          ...  ...
# 129540  1001493  11140590          광희동   중구
# 129880  1001494  11110615  종로1.2.3.4가동  종로구
# 130866  1001495  11710566          오륜동  송파구
# 130900  1001496  11680580         삼성1동  강남구
# 130934  1001491  11170650        이태원1동  용산구
#
# [1671 rows x 4 columns]

# %%
df_group2
# Out:
#     시군구명  행정동명  서비스_업종_코드_명
# 0    강남구  개포1동            7
# 1    강남구  개포2동           73
# 2    강남구  개포4동           77
# 3    강남구  논현1동           98
# 4    강남구  논현2동           98
# ..   ...   ...          ...
# 397  중랑구  상봉2동           95
# 398  중랑구  신내1동           77
# 399  중랑구  신내2동           48
# 400  중랑구  중화1동           71
# 401  중랑구  중화2동           81
#
# [402 rows x 3 columns]

# %%
# df_group2 컬럼명 변경
df_group2.columns = ["시군구명", "행정동명", "업종 개수"]

# %%
df_price = df_group2.merge(df_p, on=["시군구명", "행정동명"], how="left")
df_price
# Out:
#     시군구명  행정동명  업종 개수     분기당_매출_금액      점포수
# 0    강남구  개포1동      7  7.392885e+06      9.0
# 1    강남구  개포2동     73  1.011729e+11   3526.0
# 2    강남구  개포4동     77  1.220714e+11   2019.0
# 3    강남구  논현1동     98  1.435834e+12  22093.0
# 4    강남구  논현2동     98  5.180110e+11  11567.0
# ..   ...   ...    ...           ...      ...
# 397  중랑구  상봉2동     95  2.802949e+11   6611.0
# 398  중랑구  신내1동     77  9.467974e+10   3762.0
# 399  중랑구  신내2동     48  3.105809e+10    969.0
# 400  중랑구  중화1동     71  4.418903e+10   1861.0
# 401  중랑구  중화2동     81  1.245830e+11   4189.0
#
# [402 rows x 5 columns]

# %%
df_price = df_price.dropna(axis=0)
df_price
# Out:
#     시군구명  행정동명  업종 개수     분기당_매출_금액      점포수
# 0    강남구  개포1동      7  7.392885e+06      9.0
# 1    강남구  개포2동     73  1.011729e+11   3526.0
# 2    강남구  개포4동     77  1.220714e+11   2019.0
# 3    강남구  논현1동     98  1.435834e+12  22093.0
# 4    강남구  논현2동     98  5.180110e+11  11567.0
# ..   ...   ...    ...           ...      ...
# 397  중랑구  상봉2동     95  2.802949e+11   6611.0
# 398  중랑구  신내1동     77  9.467974e+10   3762.0
# 399  중랑구  신내2동     48  3.105809e+10    969.0
# 400  중랑구  중화1동     71  4.418903e+10   1861.0
# 401  중랑구  중화2동     81  1.245830e+11   4189.0
#
# [401 rows x 5 columns]

# %%
corr = df_price.corr()
mask = np.triu(np.ones_like(corr))

# %%
plt.figure(figsize=(15,5))
sns.heatmap(corr, cmap="coolwarm", annot =True, fmt=".2f", vmin=-1,vmax=1,mask=mask)
plt.title("매출과 업종 데이터셋 상관계수", fontsize=15)
# Out:
# Text(0.5, 1.0, '매출과 업종 데이터셋 상관계수')

# %% [markdown]
# ## 스트림릿 순위 추출

# %% [markdown]
# ### 행정동별 매출, 점포수 순위

# %%
시군구 = np.random.choice(df_price["시군구명"].unique())
시군구
# Out:
# '동대문구'

# %%
행정동 = np.random.choice(df_price.loc[df_price["시군구명"]==시군구,"행정동명"].unique())
행정동
# Out:
# '답십리2동'

# %%
df_big = df_price[(df_price["시군구명"]==시군구)]
df_big
# Out:
#      시군구명   행정동명  업종 개수     분기당_매출_금액      점포수
# 157  동대문구  답십리1동     79  1.335222e+11   2885.0
# 158  동대문구  답십리2동     74  8.473812e+10   2905.0
# 159  동대문구    용신동     93  4.173900e+11   8992.0
# 160  동대문구   이문1동     69  5.802239e+10   2825.0
# 161  동대문구   이문2동     22  2.539502e+09    111.0
# 162  동대문구   장안1동     92  4.737781e+11   9316.0
# 163  동대문구   장안2동     87  4.062527e+11   9800.0
# 164  동대문구   전농1동     88  1.734116e+11   5802.0
# 165  동대문구   전농2동     49  1.742773e+10    652.0
# 166  동대문구    제기동     91  2.434650e+12  13953.0
# 167  동대문구   청량리동     50  9.612259e+09    666.0
# 168  동대문구    회기동     74  1.226755e+11   5029.0
# 169  동대문구   휘경1동     74  6.117176e+10   2599.0
# 170  동대문구   휘경2동     55  5.237204e+10   1120.0

# %%
df_big[["분기당_매출_금액", "점포수"]].rank(method='min', ascending=False).astype(int)
# Out:
#      분기당_매출_금액  점포수
# 157          6    8
# 158          8    7
# 159          3    4
# 160         10    9
# 161         14   14
# 162          2    3
# 163          4    2
# 164          5    5
# 165         12   13
# 166          1    1
# 167         13   12
# 168          7    6
# 169          9   10
# 170         11   11

# %% [markdown]
# ### 행정동별 연령대 순위

# %%
df_age = pd.read_csv("data/df_age_melt.csv", encoding="utf-8")
df_age.head(10)
# Out:
#    기준 연도  분기 시군구명         행정동명 상주인구 연령대  상주인구 연령대별 수
# 0   2022   2  강남구         삼성1동      10대            2
# 1   2022   2  송파구          오륜동      10대          819
# 2   2022   2  종로구  종로1.2.3.4가동      10대           45
# 3   2022   2   중구          광희동      10대          189
# 4   2022   2   중구          소공동      10대           17
# 5   2022   2  용산구        이태원1동      10대          329
# 6   2022   2  강동구         고덕2동      10대          255
# 7   2022   2  강동구         명일1동      10대          341
# 8   2022   2  강동구           길동      10대          118
# 9   2022   2  강동구         성내3동      10대          152

# %%
df_new_age = df_price.merge(df_age, on = ["시군구명", "행정동명"], how="left")
df_new_age = df_new_age.drop(["분기"], axis=1)
df_new_age = df_new_age[df_new_age['기준 연도'] == 2021.0]
df_new_age
# Out:
#        시군구명  행정동명  업종 개수     분기당_매출_금액     점포수   기준 연도 상주인구 연령대  상주인구 연령대별 수
# 2       강남구  개포1동      7  7.392885e+06     9.0  2021.0      10대         27.0
# 3       강남구  개포1동      7  7.392885e+06     9.0  2021.0      10대         27.0
# 4       강남구  개포1동      7  7.392885e+06     9.0  2021.0      10대         27.0
# 5       강남구  개포1동      7  7.392885e+06     9.0  2021.0      10대         27.0
# 24      강남구  개포1동      7  7.392885e+06     9.0  2021.0      20대         36.0
# ...     ...   ...    ...           ...     ...     ...      ...          ...
# 215200  중랑구  중화2동     81  1.245830e+11  4189.0  2021.0      60대         85.0
# 215201  중랑구  중화2동     81  1.245830e+11  4189.0  2021.0      60대        397.0
# 215202  중랑구  중화2동     81  1.245830e+11  4189.0  2021.0      60대        431.0
# 215203  중랑구  중화2동     81  1.245830e+11  4189.0  2021.0      60대        121.0
# 215204  중랑구  중화2동     81  1.245830e+11  4189.0  2021.0      60대       1519.0
#
# [39120 rows x 8 columns]

# %%
시군구 = np.random.choice(df_new_age["시군구명"].unique())
시군구
# Out:
# '광진구'

# %%
행정동 = np.random.choice(df_new_age.loc[df_new_age["시군구명"]==시군구,"행정동명"].unique())
행정동
# Out:
# '화양동'

# %%
df_big = df_new_age[(df_new_age["시군구명"]==시군구)]
df_big
# Out:
#       시군구명 행정동명  업종 개수     분기당_매출_금액      점포수   기준 연도 상주인구 연령대  상주인구 연령대별 수
# 48186  광진구  광장동     75  5.309723e+10   1557.0  2021.0      10대        197.0
# 48187  광진구  광장동     75  5.309723e+10   1557.0  2021.0      10대        130.0
# 48188  광진구  광장동     75  5.309723e+10   1557.0  2021.0      10대        164.0
# 48189  광진구  광장동     75  5.309723e+10   1557.0  2021.0      10대        197.0
# 48190  광진구  광장동     75  5.309723e+10   1557.0  2021.0      10대        130.0
# ...    ...  ...    ...           ...      ...     ...      ...          ...
# 56231  광진구  화양동     93  4.677758e+11  14663.0  2021.0      60대       1128.0
# 56232  광진구  화양동     93  4.677758e+11  14663.0  2021.0      60대        289.0
# 56233  광진구  화양동     93  4.677758e+11  14663.0  2021.0      60대        377.0
# 56234  광진구  화양동     93  4.677758e+11  14663.0  2021.0      60대        644.0
# 56235  광진구  화양동     93  4.677758e+11  14663.0  2021.0      60대        471.0
#
# [1488 rows x 8 columns]

# %%
df_new_big = df_big.groupby("상주인구 연령대")[["상주인구 연령대별 수"]].sum()
df_new_big
# Out:
#           상주인구 연령대별 수
# 상주인구 연령대
# 10대           80128.0
# 20대          162268.0
# 30대          138484.0
# 40대          109876.0
# 50대          120908.0
# 60대          178736.0

# %%
df_new_big[["상주인구 연령대별 수"]].rank(method='min', ascending=False).astype(int)
# Out:
#           상주인구 연령대별 수
# 상주인구 연령대
# 10대                 6
# 20대                 2
# 30대                 3
# 40대                 5
# 50대                 4
# 60대                 1
